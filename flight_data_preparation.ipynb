# %%
import pandas as pd

# %%
csv_files = ['Flight_Info_and_Weather_Data_Cihan.csv', 'Flight_Info_and_Weather_Data_Cihan2.csv', 
             'Flight_Info_and_Weather_Data_Ericson.csv', 'Flight_Info_and_Weather_Data_Ericson2.csv'
             , 'Flight_Info_and_Weather_Data_Pawan.csv', 'Flight_Info_and_Weather_Data_Sumanth.csv'
            , 'Flight_Info_and_Weather_Data_William.csv']

df_csv_concat = pd.DataFrame()
final = pd.DataFrame()

df_csv_concat = pd.concat([pd.read_csv(file) for file in csv_files ], ignore_index=True)

# df_csv_concat
final = df_csv_concat.drop(['date', 'date.1','CRS_DEP_TIME','DEP_TIME','TAXI_OUT','WHEELS_OFF','ORIGIN','DEST', 'DEP_DELAY'], axis=1)

final = final.dropna()

# %%
final.head(10)
# Out:
#       FL_DATE  DOT_CODE  FL_NUMBER  CRS_ARR_TIME  ARR_DELAY  CRS_ELAPSED_TIME  \
# 0  2022-04-22     20304       3032          1605       26.0              68.0
# 1  2021-04-29     20398       3908          1844       18.0              81.0
# 2  2021-05-11     19393       2646          1550       15.0             170.0
# 3  2019-03-01     19790       2957          2339       68.0             129.0
# 4  2022-05-05     20436        769            15       90.0             118.0
# 5  2022-04-30     20416        954           605      107.0             275.0
# 6  2019-03-19     19805       1116          1737       52.0              66.0
# 7  2019-11-20     19393       1810          1640       30.0             120.0
# 8  2019-06-08     20304       5572          2149       44.0             114.0
# 9  2022-06-27     20368        367          1832       28.0             111.0
#
#    DISTANCE  ORIGIN_ABE  ORIGIN_ABI  ORIGIN_ABQ  ...  dest_wind_speed_10m  \
# ...

# %%
final.to_csv('complete_flight_info_and weather_data.csv', index=False)  
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29398 entries, 0 to 31149
# Columns: 760 entries, FL_DATE to dest_snow_depth
# dtypes: bool(727), float64(28), int64(4), object(1)
# memory usage: 28.0+ MB
